# %%
def replace_chars_with_colon(input_string):
    # Define the characters to replace with a colon
    chars_to_replace = [' ', ',', '.']
    replacement = ':'

    # Replace characters in the input string
    for char in chars_to_replace:
        input_string = input_string.replace(char, replacement)

    return input_string

# Test the function
if __name__ == "__main__":
    input_string = input("Enter a string: ")
    result = replace_chars_with_colon(input_string)
    print("Result:", result)
# Out:
# Enter a string: Python Exercises, PHP exercises.
# Result: Python:Exercises::PHP:exercises:

# %%
import re

def find_words_starting_with_a_or_e(input_string):
    # Define the regular expression pattern to find words starting with 'a' or 'e'
    pattern = r'\b[aeAE]\w*\b'
    
    # Find all matches using the pattern
    matches = re.findall(pattern, input_string)
    
    return matches

# Test the function
if __name__ == "__main__":
    input_string = input("Enter a string: ")
    result = find_words_starting_with_a_or_e(input_string)
    print("Words starting with 'a' or 'e':", result)
# Out:
# Enter a string: An Aeroplane can fly but an Elephant can't.
# Words starting with 'a' or 'e': ['An', 'Aeroplane', 'an', 'Elephant']

# %%
import re

def find_long_words(input_string):
    # Compile the regular expression pattern to match words at least 4 characters long
    pattern = re.compile(r'\b\w{4,}\b')
    
    # Find all matches using the compiled pattern
    matches = pattern.findall(input_string)
    
    return matches

# Test the function
if __name__ == "__main__":
    input_string = input("Enter a string: ")
    result = find_long_words(input_string)
    print("Words at least 4 characters long:", result)
# Out:
# Enter a string: my Uncle has got a huge garden and a very large farm house.
# Words at least 4 characters long: ['Uncle', 'huge', 'garden', 'very', 'large', 'farm', 'house']

# %%
import re

def find_words_with_length(input_string, min_length, max_length):
    # Compile the regular expression pattern to match words of specified length range
    pattern = re.compile(r'\b\w{' + str(min_length) + ',' + str(max_length) + r'}\b')
    
    # Find all matches using the compiled pattern
    matches = pattern.findall(input_string)
    
    return matches

# Test the function
if __name__ == "__main__":
    input_string = input("Enter a string: ")
    min_length = 3
    max_length = 5
    result = find_words_with_length(input_string, min_length, max_length)
    print(f"Words with {min_length}-{max_length} characters:", result)
# Out:
# Enter a string: This is to inform that cat has eaten a rat, and other rats are hiden out
# Words with 3-5 characters: ['This', 'that', 'cat', 'has', 'eaten', 'rat', 'and', 'other', 'rats', 'are', 'hiden', 'out']

# %%
import re

def remove_parentheses(strings_list):
    # Question 5- Create a function in Python to remove the parenthesis in a list of strings.The use of the re.compile() method is mandatory.
    pattern = re.compile(r'\(|\)')

    # Remove parentheses from each string in the list
    sanitized_list = [pattern.sub('', string) for string in strings_list]

    return sanitized_list

# Test the function
if __name__ == "__main__":
    input_list = ["example (.com)", "hr@fliprobo (.com)", "github (.com)", "Hello (Data Science World)", "Data (Scientist)"]
    result = remove_parentheses(input_list)
    print("List with parentheses removed:", result)
# Out:
# List with parentheses removed: ['example .com', 'hr@fliprobo .com', 'github .com', 'Hello Data Science World', 'Data Scientist']

# %%
import re

def split_uppercase(string):
    pattern = r'(?=[A-Z])'
    uppercase_parts = re.split(pattern, string)
    uppercase_parts = [part for part in uppercase_parts if part != '']
    return uppercase_parts

if __name__ == "__main__":
    input_string = "ImportanceOfRegularExpressionsInPython"
    result = split_uppercase(input_string)
    print("Uppercase parts:", result)
# Out:
# Uppercase parts: ['Importance', 'Of', 'Regular', 'Expressions', 'In', 'Python']

# %%
import re

def insert_spaces_between_numbers_and_words(input_string):
    pattern = r'(\d)([A-Za-z]+)'
    modified_string = re.sub(pattern, r'\1 \2', input_string)
    return modified_string

# Test the function
if __name__ == "__main__":
    input_string = "RegularExpression1IsAn2ImportantTopic3InPython"
    result = insert_spaces_between_numbers_and_words(input_string)
    print("Modified string:", result)
# Out:
# Modified string: RegularExpression1 IsAn2 ImportantTopic3 InPython

# %%
import re

def insert_spaces_between_caps_and_numbers(input_string):
    pattern = r'([A-Z\d])([a-z]+)'
    modified_string = re.sub(pattern, r'\1 \2', input_string)
    return modified_string

# Test the function
if __name__ == "__main__":
    input_string = "RegularExpression1IsAn2ImportantTopic3InPython"
    result = insert_spaces_between_caps_and_numbers(input_string)
    print("Modified string:", result)
# Out:
# Modified string: R egularE xpression1I sA n2I mportantT opic3I nP ython

# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
'c:\\users\\text'
# Out:
# 'c:\\users\\text'

# %%
os.chdir('C:\\Users\\text\\Desktop')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 os.chdir('C:\\Users\\text\\Desktop')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\text\\Desktop'

# %%
import re

def extract_email_addresses(text):
    pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,7}\b'
    email_addresses = re.findall(pattern, text, re.IGNORECASE)
    return email_addresses

def process_file(input_file):
    with open(input_file, 'r') as file:
        content = file.read()
        
    extracted_emails = extract_email_addresses(content)
    
    if extracted_emails:
        print("Extracted email addresses:")
        for email in extracted_emails:
            print(email)
    else:
        print("No email addresses found in the text.")

if __name__ == "__main__":
    input_file_name = "text.txt"   # Replace with your input file name
    
    process_file(input_file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 24
#      21 if __name__ == "__main__":
#      22     input_file_name = "text.txt"   # Replace with your input file name
# ---> 24     process_file(input_file_name)
#
# Cell In[20], line 9, in process_file(input_file)
#       8 def process_file(input_file):
# ----> 9     with open(input_file, 'r') as file:
#      10         content = file.read()
#      12     extracted_emails = extract_email_addresses(content)
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text.txt'

# %%
import re

def is_valid_string(input_string):
    pattern = r'^[A-Za-z0-9_]+$'
    return re.match(pattern, input_string) is not None

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    if is_valid_string(input_string):
        print("The string is valid.")
    else:
        print("The string is not valid.")
# Out:
# Enter a string: Kush_agra IS good Man
# The string is not valid.

# %%
def starts_with_number(input_string, number):
    return input_string.startswith(str(number))

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    specific_number = 42  # Replace with the specific number you want to check
    
    if starts_with_number(input_string, specific_number):
        print("The string starts with the specific number.")
    else:
        print("The string does not start with the specific number.")
# Out:
# Enter a string: 42_Volloby West, australia
# The string starts with the specific number.

# %%
def remove_leading_zeros(ip_address):
    components = ip_address.split('.')
    normalized_components = [str(int(component)) for component in components]
    normalized_ip = '.'.join(normalized_components)
    return normalized_ip

if __name__ == "__main__":
    ip_address = input("Enter an IP address: ")
    normalized_ip = remove_leading_zeros(ip_address)
    print("IP address without leading zeros:", normalized_ip)
# Out:
# Enter an IP address: 192.168. 1.0
# IP address without leading zeros: 192.168.1.0

# %%
import re

def extract_dates_from_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()

    pattern = r'\b(?:January|February|March|April|May|June|July|August|September|October|November|December)\s+\d{1,2},\s+\d{4}\b'
    dates = re.findall(pattern, content, re.IGNORECASE)
    return dates

if __name__ == "__main__":
    file_path = "dates.txt"  # Replace with your file path
    
    extracted_dates = extract_dates_from_file(file_path)
    if extracted_dates:
        print("Extracted dates:")
        for date in extracted_dates:
            print(date)
    else:
        print("No valid dates found in the text file.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 14
#      11 if __name__ == "__main__":
#      12     file_path = "dates.txt"  # Replace with your file path
# ---> 14     extracted_dates = extract_dates_from_file(file_path)
#      15     if extracted_dates:
#      16         print("Extracted dates:")
#
# Cell In[34], line 4, in extract_dates_from_file(file_path)
#       3 def extract_dates_from_file(file_path):
# ----> 4     with open(file_path, 'r') as file:
#       5         content = file.read()
#       7     pattern = r'\b(?:January|February|March|April|May|June|July|August|September|October|November|December)\s+\d{1,2},\s+\d{4}\b'
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dates.txt'

# %%
import re

def search_strings_with_regex(text, literals):
    pattern = '|'.join(re.escape(literal) for literal in literals)
    matches = re.findall(pattern, text, re.IGNORECASE)
    return matches

if __name__ == "__main__":
    main_string = "The quick brown fox jumps over the lazy dog."
    search_literals = ["sample", "literals", "search"]
    
    found_strings = search_strings_with_regex(main_string, search_literals)
    
    if found_strings:
        print("Found strings:")
        for found_string in found_strings:
            print(found_string)
    else:
        print("No matches found.")
# Out:
# No matches found.

# %%
import re

def search_strings_with_positions_and_regex(text, literals):
    pattern = '|'.join(re.escape(literal) for literal in literals)
    matches = re.finditer(pattern, text, re.IGNORECASE)
    found_strings = [(match.group(), match.start()) for match in matches]
    return found_strings

if __name__ == "__main__":
    main_string = "The quick brown fox jumps over the lazy dog."
    search_literals = ["dog", "fox"]
    
    found_strings = search_strings_with_positions_and_regex(main_string, search_literals)
    
    if found_strings:
        print("Found strings and their positions:")
        for found_string, position in found_strings:
            print(f"'{found_string}' found at position {position}")
    else:
        print("No matches found.")
# Out:
# Found strings and their positions:
# 'fox' found at position 16
# 'dog' found at position 40

# %%
def find_substrings(input_string):
    substrings = [input_string[i:j] for i in range(len(input_string)) for j in range(i + 1, len(input_string) + 1)]
    return substrings

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    substrings = find_substrings(input_string)
    
    print("Found substrings:")
    for substring in substrings:
        print(substring)
# Out:
# Enter a string: Python exercises, PHP exercises, C# exercises
# Found substrings:
# P
# Py
# Pyt
# Pyth
# Pytho
# Python
# Python
# Python e
# Python ex
# Python exe
# Python exer
# Python exerc
# Python exerci
# Python exercis
# Python exercise
# Python exercises
# Python exercises,
# Python exercises,
# Python exercises, P
# Python exercises, PH
# Python exercises, PHP
# Python exercises, PHP
# Python exercises, PHP e
# Python exercises, PHP ex
# Python exercises, PHP exe
# Python exercises, PHP exer
# Python exercises, PHP exerc
# Python exercises, PHP exerci
# Python exercises, PHP exercis
# Python exercises, PHP exercise
# Python exercises, PHP exercises
# Python exercises, PHP exercises,
# Python exercises, PHP exercises,
# Python exercises, PHP exercises, C
# Python exercises, PHP exercises, C#
# Python exercises, PHP exercises, C#
# Python exercises, PHP exercises, C# e
# Python exercises, PHP exercises, C# ex
# Python exercises, PHP exercises, C# exe
# Python exercises, PHP exercises, C# exer
# Python exercises, PHP exercises, C# exerc
# Python exercises, PHP exercises, C# exerci
# Python exercises, PHP exercises, C# exercis
# Python exercises, PHP exercises, C# exercise
# Python exercises, PHP exercises, C# exercises
# y
# yt
# yth
# ytho
# ython
# ython
# ython e
# ython ex
# ython exe
# ython exer
# ython exerc
# ython exerci
# ython exercis
# ython exercise
# ython exercises
# ython exercises,
# ython exercises,
# ython exercises, P
# ython exercises, PH
# ython exercises, PHP
# ython exercises, PHP
# ython exercises, PHP e
# ython exercises, PHP ex
# ython exercises, PHP exe
# ython exercises, PHP exer
# ython exercises, PHP exerc
# ython exercises, PHP exerci
# ython exercises, PHP exercis
# ython exercises, PHP exercise
# ython exercises, PHP exercises
# ython exercises, PHP exercises,
# ython exercises, PHP exercises,
# ython exercises, PHP exercises, C
# ython exercises, PHP exercises, C#
# ython exercises, PHP exercises, C#
# ython exercises, PHP exercises, C# e
# ython exercises, PHP exercises, C# ex
# ython exercises, PHP exercises, C# exe
# ython exercises, PHP exercises, C# exer
# ython exercises, PHP exercises, C# exerc
# ython exercises, PHP exercises, C# exerci
# ython exercises, PHP exercises, C# exercis
# ython exercises, PHP exercises, C# exercise
# ython exercises, PHP exercises, C# exercises
# t
# th
# tho
# thon
# thon
# thon e
# thon ex
# thon exe
# thon exer
# thon exerc
# thon exerci
# thon exercis
# thon exercise
# thon exercises
# thon exercises,
# thon exercises,
# thon exercises, P
# thon exercises, PH
# thon exercises, PHP
# thon exercises, PHP
# thon exercises, PHP e
# thon exercises, PHP ex
# thon exercises, PHP exe
# thon exercises, PHP exer
# thon exercises, PHP exerc
# thon exercises, PHP exerci
# thon exercises, PHP exercis
# thon exercises, PHP exercise
# thon exercises, PHP exercises
# thon exercises, PHP exercises,
# thon exercises, PHP exercises,
# thon exercises, PHP exercises, C
# thon exercises, PHP exercises, C#
# thon exercises, PHP exercises, C#
# thon exercises, PHP exercises, C# e
# thon exercises, PHP exercises, C# ex
# thon exercises, PHP exercises, C# exe
# thon exercises, PHP exercises, C# exer
# thon exercises, PHP exercises, C# exerc
# thon exercises, PHP exercises, C# exerci
# thon exercises, PHP exercises, C# exercis
# thon exercises, PHP exercises, C# exercise
# thon exercises, PHP exercises, C# exercises
# h
# ho
# hon
# hon
# hon e
# hon ex
# hon exe
# hon exer
# hon exerc
# hon exerci
# hon exercis
# hon exercise
# hon exercises
# hon exercises,
# hon exercises,
# hon exercises, P
# hon exercises, PH
# hon exercises, PHP
# hon exercises, PHP
# hon exercises, PHP e
# hon exercises, PHP ex
# hon exercises, PHP exe
# hon exercises, PHP exer
# hon exercises, PHP exerc
# hon exercises, PHP exerci
# hon exercises, PHP exercis
# hon exercises, PHP exercise
# hon exercises, PHP exercises
# hon exercises, PHP exercises,
# hon exercises, PHP exercises,
# hon exercises, PHP exercises, C
# hon exercises, PHP exercises, C#
# hon exercises, PHP exercises, C#
# hon exercises, PHP exercises, C# e
# hon exercises, PHP exercises, C# ex
# hon exercises, PHP exercises, C# exe
# hon exercises, PHP exercises, C# exer
# hon exercises, PHP exercises, C# exerc
# hon exercises, PHP exercises, C# exerci
# hon exercises, PHP exercises, C# exercis
# hon exercises, PHP exercises, C# exercise
# hon exercises, PHP exercises, C# exercises
# o
# on
# on
# on e
# on ex
# on exe
# on exer
# on exerc
# on exerci
# on exercis
# on exercise
# on exercises
# on exercises,
# on exercises,
# on exercises, P
# on exercises, PH
# on exercises, PHP
# on exercises, PHP
# on exercises, PHP e
# on exercises, PHP ex
# on exercises, PHP exe
# on exercises, PHP exer
# on exercises, PHP exerc
# on exercises, PHP exerci
# on exercises, PHP exercis
# on exercises, PHP exercise
# on exercises, PHP exercises
# on exercises, PHP exercises,
# on exercises, PHP exercises,
# on exercises, PHP exercises, C
# on exercises, PHP exercises, C#
# on exercises, PHP exercises, C#
# on exercises, PHP exercises, C# e
# on exercises, PHP exercises, C# ex
# on exercises, PHP exercises, C# exe
# on exercises, PHP exercises, C# exer
# on exercises, PHP exercises, C# exerc
# on exercises, PHP exercises, C# exerci
# on exercises, PHP exercises, C# exercis
# on exercises, PHP exercises, C# exercise
# on exercises, PHP exercises, C# exercises
# n
# n
# n e
# n ex
# n exe
# n exer
# n exerc
# n exerci
# n exercis
# n exercise
# n exercises
# n exercises,
# n exercises,
# n exercises, P
# n exercises, PH
# n exercises, PHP
# n exercises, PHP
# n exercises, PHP e
# n exercises, PHP ex
# n exercises, PHP exe
# n exercises, PHP exer
# n exercises, PHP exerc
# n exercises, PHP exerci
# n exercises, PHP exercis
# n exercises, PHP exercise
# n exercises, PHP exercises
# n exercises, PHP exercises,
# n exercises, PHP exercises,
# n exercises, PHP exercises, C
# n exercises, PHP exercises, C#
# n exercises, PHP exercises, C#
# n exercises, PHP exercises, C# e
# n exercises, PHP exercises, C# ex
# n exercises, PHP exercises, C# exe
# n exercises, PHP exercises, C# exer
# n exercises, PHP exercises, C# exerc
# n exercises, PHP exercises, C# exerci
# n exercises, PHP exercises, C# exercis
# n exercises, PHP exercises, C# exercise
# n exercises, PHP exercises, C# exercises
#
#  e
#  ex
#  exe
#  exer
#  exerc
#  exerci
#  exercis
#  exercise
#  exercises
#  exercises,
#  exercises,
#  exercises, P
#  exercises, PH
#  exercises, PHP
#  exercises, PHP
#  exercises, PHP e
#  exercises, PHP ex
#  exercises, PHP exe
#  exercises, PHP exer
#  exercises, PHP exerc
#  exercises, PHP exerci
#  exercises, PHP exercis
#  exercises, PHP exercise
#  exercises, PHP exercises
#  exercises, PHP exercises,
#  exercises, PHP exercises,
#  exercises, PHP exercises, C
#  exercises, PHP exercises, C#
#  exercises, PHP exercises, C#
#  exercises, PHP exercises, C# e
#  exercises, PHP exercises, C# ex
#  exercises, PHP exercises, C# exe
#  exercises, PHP exercises, C# exer
#  exercises, PHP exercises, C# exerc
#  exercises, PHP exercises, C# exerci
#  exercises, PHP exercises, C# exercis
#  exercises, PHP exercises, C# exercise
#  exercises, PHP exercises, C# exercises
# e
# ex
# exe
# exer
# exerc
# exerci
# exercis
# exercise
# exercises
# exercises,
# exercises,
# exercises, P
# exercises, PH
# exercises, PHP
# exercises, PHP
# exercises, PHP e
# exercises, PHP ex
# exercises, PHP exe
# exercises, PHP exer
# exercises, PHP exerc
# exercises, PHP exerci
# exercises, PHP exercis
# exercises, PHP exercise
# exercises, PHP exercises
# exercises, PHP exercises,
# exercises, PHP exercises,
# exercises, PHP exercises, C
# exercises, PHP exercises, C#
# exercises, PHP exercises, C#
# exercises, PHP exercises, C# e
# exercises, PHP exercises, C# ex
# exercises, PHP exercises, C# exe
# exercises, PHP exercises, C# exer
# exercises, PHP exercises, C# exerc
# exercises, PHP exercises, C# exerci
# exercises, PHP exercises, C# exercis
# exercises, PHP exercises, C# exercise
# exercises, PHP exercises, C# exercises
# x
# xe
# xer
# xerc
# xerci
# xercis
# xercise
# xercises
# xercises,
# xercises,
# xercises, P
# xercises, PH
# xercises, PHP
# xercises, PHP
# xercises, PHP e
# xercises, PHP ex
# xercises, PHP exe
# xercises, PHP exer
# xercises, PHP exerc
# xercises, PHP exerci
# xercises, PHP exercis
# xercises, PHP exercise
# xercises, PHP exercises
# xercises, PHP exercises,
# xercises, PHP exercises,
# xercises, PHP exercises, C
# xercises, PHP exercises, C#
# xercises, PHP exercises, C#
# xercises, PHP exercises, C# e
# xercises, PHP exercises, C# ex
# xercises, PHP exercises, C# exe
# xercises, PHP exercises, C# exer
# xercises, PHP exercises, C# exerc
# xercises, PHP exercises, C# exerci
# xercises, PHP exercises, C# exercis
# xercises, PHP exercises, C# exercise
# xercises, PHP exercises, C# exercises
# e
# er
# erc
# erci
# ercis
# ercise
# ercises
# ercises,
# ercises,
# ercises, P
# ercises, PH
# ercises, PHP
# ercises, PHP
# ercises, PHP e
# ercises, PHP ex
# ercises, PHP exe
# ercises, PHP exer
# ercises, PHP exerc
# ercises, PHP exerci
# ercises, PHP exercis
# ercises, PHP exercise
# ercises, PHP exercises
# ercises, PHP exercises,
# ercises, PHP exercises,
# ercises, PHP exercises, C
# ercises, PHP exercises, C#
# ercises, PHP exercises, C#
# ercises, PHP exercises, C# e
# ercises, PHP exercises, C# ex
# ercises, PHP exercises, C# exe
# ercises, PHP exercises, C# exer
# ercises, PHP exercises, C# exerc
# ercises, PHP exercises, C# exerci
# ercises, PHP exercises, C# exercis
# ercises, PHP exercises, C# exercise
# ercises, PHP exercises, C# exercises
# r
# rc
# rci
# rcis
# rcise
# rcises
# rcises,
# rcises,
# rcises, P
# rcises, PH
# rcises, PHP
# rcises, PHP
# rcises, PHP e
# rcises, PHP ex
# rcises, PHP exe
# rcises, PHP exer
# rcises, PHP exerc
# rcises, PHP exerci
# rcises, PHP exercis
# rcises, PHP exercise
# rcises, PHP exercises
# rcises, PHP exercises,
# rcises, PHP exercises,
# rcises, PHP exercises, C
# rcises, PHP exercises, C#
# rcises, PHP exercises, C#
# rcises, PHP exercises, C# e
# rcises, PHP exercises, C# ex
# rcises, PHP exercises, C# exe
# rcises, PHP exercises, C# exer
# rcises, PHP exercises, C# exerc
# rcises, PHP exercises, C# exerci
# rcises, PHP exercises, C# exercis
# rcises, PHP exercises, C# exercise
# rcises, PHP exercises, C# exercises
# c
# ci
# cis
# cise
# cises
# cises,
# cises,
# cises, P
# cises, PH
# cises, PHP
# cises, PHP
# cises, PHP e
# cises, PHP ex
# cises, PHP exe
# cises, PHP exer
# cises, PHP exerc
# cises, PHP exerci
# cises, PHP exercis
# cises, PHP exercise
# cises, PHP exercises
# cises, PHP exercises,
# cises, PHP exercises,
# cises, PHP exercises, C
# cises, PHP exercises, C#
# cises, PHP exercises, C#
# cises, PHP exercises, C# e
# cises, PHP exercises, C# ex
# cises, PHP exercises, C# exe
# cises, PHP exercises, C# exer
# cises, PHP exercises, C# exerc
# cises, PHP exercises, C# exerci
# cises, PHP exercises, C# exercis
# cises, PHP exercises, C# exercise
# cises, PHP exercises, C# exercises
# i
# is
# ise
# ises
# ises,
# ises,
# ises, P
# ises, PH
# ises, PHP
# ises, PHP
# ises, PHP e
# ises, PHP ex
# ises, PHP exe
# ises, PHP exer
# ises, PHP exerc
# ises, PHP exerci
# ises, PHP exercis
# ises, PHP exercise
# ises, PHP exercises
# ises, PHP exercises,
# ises, PHP exercises,
# ises, PHP exercises, C
# ises, PHP exercises, C#
# ises, PHP exercises, C#
# ises, PHP exercises, C# e
# ises, PHP exercises, C# ex
# ises, PHP exercises, C# exe
# ises, PHP exercises, C# exer
# ises, PHP exercises, C# exerc
# ises, PHP exercises, C# exerci
# ises, PHP exercises, C# exercis
# ises, PHP exercises, C# exercise
# ises, PHP exercises, C# exercises
# s
# se
# ses
# ses,
# ses,
# ses, P
# ses, PH
# ses, PHP
# ses, PHP
# ses, PHP e
# ses, PHP ex
# ses, PHP exe
# ses, PHP exer
# ses, PHP exerc
# ses, PHP exerci
# ses, PHP exercis
# ses, PHP exercise
# ses, PHP exercises
# ses, PHP exercises,
# ses, PHP exercises,
# ses, PHP exercises, C
# ses, PHP exercises, C#
# ses, PHP exercises, C#
# ses, PHP exercises, C# e
# ses, PHP exercises, C# ex
# ses, PHP exercises, C# exe
# ses, PHP exercises, C# exer
# ses, PHP exercises, C# exerc
# ses, PHP exercises, C# exerci
# ses, PHP exercises, C# exercis
# ses, PHP exercises, C# exercise
# ses, PHP exercises, C# exercises
# e
# es
# es,
# es,
# es, P
# es, PH
# es, PHP
# es, PHP
# es, PHP e
# es, PHP ex
# es, PHP exe
# es, PHP exer
# es, PHP exerc
# es, PHP exerci
# es, PHP exercis
# es, PHP exercise
# es, PHP exercises
# es, PHP exercises,
# es, PHP exercises,
# es, PHP exercises, C
# es, PHP exercises, C#
# es, PHP exercises, C#
# es, PHP exercises, C# e
# es, PHP exercises, C# ex
# es, PHP exercises, C# exe
# es, PHP exercises, C# exer
# es, PHP exercises, C# exerc
# es, PHP exercises, C# exerci
# es, PHP exercises, C# exercis
# es, PHP exercises, C# exercise
# es, PHP exercises, C# exercises
# s
# s,
# s,
# s, P
# s, PH
# s, PHP
# s, PHP
# s, PHP e
# s, PHP ex
# s, PHP exe
# s, PHP exer
# s, PHP exerc
# s, PHP exerci
# s, PHP exercis
# s, PHP exercise
# s, PHP exercises
# s, PHP exercises,
# s, PHP exercises,
# s, PHP exercises, C
# s, PHP exercises, C#
# s, PHP exercises, C#
# s, PHP exercises, C# e
# s, PHP exercises, C# ex
# s, PHP exercises, C# exe
# s, PHP exercises, C# exer
# s, PHP exercises, C# exerc
# s, PHP exercises, C# exerci
# s, PHP exercises, C# exercis
# s, PHP exercises, C# exercise
# s, PHP exercises, C# exercises
# ,
# ,
# , P
# , PH
# , PHP
# , PHP
# , PHP e
# , PHP ex
# , PHP exe
# , PHP exer
# , PHP exerc
# , PHP exerci
# , PHP exercis
# , PHP exercise
# , PHP exercises
# , PHP exercises,
# , PHP exercises,
# , PHP exercises, C
# , PHP exercises, C#
# , PHP exercises, C#
# , PHP exercises, C# e
# , PHP exercises, C# ex
# , PHP exercises, C# exe
# , PHP exercises, C# exer
# , PHP exercises, C# exerc
# , PHP exercises, C# exerci
# , PHP exercises, C# exercis
# , PHP exercises, C# exercise
# , PHP exercises, C# exercises
#
#  P
#  PH
#  PHP
#  PHP
#  PHP e
#  PHP ex
#  PHP exe
#  PHP exer
#  PHP exerc
#  PHP exerci
#  PHP exercis
#  PHP exercise
#  PHP exercises
#  PHP exercises,
#  PHP exercises,
#  PHP exercises, C
#  PHP exercises, C#
#  PHP exercises, C#
#  PHP exercises, C# e
#  PHP exercises, C# ex
#  PHP exercises, C# exe
#  PHP exercises, C# exer
#  PHP exercises, C# exerc
#  PHP exercises, C# exerci
#  PHP exercises, C# exercis
#  PHP exercises, C# exercise
#  PHP exercises, C# exercises
# P
# PH
# PHP
# PHP
# PHP e
# PHP ex
# PHP exe
# PHP exer
# PHP exerc
# PHP exerci
# PHP exercis
# PHP exercise
# PHP exercises
# PHP exercises,
# PHP exercises,
# PHP exercises, C
# PHP exercises, C#
# PHP exercises, C#
# PHP exercises, C# e
# PHP exercises, C# ex
# PHP exercises, C# exe
# PHP exercises, C# exer
# PHP exercises, C# exerc
# PHP exercises, C# exerci
# PHP exercises, C# exercis
# PHP exercises, C# exercise
# PHP exercises, C# exercises
# H
# HP
# HP
# HP e
# HP ex
# HP exe
# HP exer
# HP exerc
# HP exerci
# HP exercis
# HP exercise
# HP exercises
# HP exercises,
# HP exercises,
# HP exercises, C
# HP exercises, C#
# HP exercises, C#
# HP exercises, C# e
# HP exercises, C# ex
# HP exercises, C# exe
# HP exercises, C# exer
# HP exercises, C# exerc
# HP exercises, C# exerci
# HP exercises, C# exercis
# HP exercises, C# exercise
# HP exercises, C# exercises
# P
# P
# P e
# P ex
# P exe
# P exer
# P exerc
# P exerci
# P exercis
# P exercise
# P exercises
# P exercises,
# P exercises,
# P exercises, C
# P exercises, C#
# P exercises, C#
# P exercises, C# e
# P exercises, C# ex
# P exercises, C# exe
# P exercises, C# exer
# P exercises, C# exerc
# P exercises, C# exerci
# P exercises, C# exercis
# P exercises, C# exercise
# P exercises, C# exercises
#
#  e
#  ex
#  exe
#  exer
#  exerc
#  exerci
#  exercis
#  exercise
#  exercises
#  exercises,
#  exercises,
#  exercises, C
#  exercises, C#
#  exercises, C#
#  exercises, C# e
#  exercises, C# ex
#  exercises, C# exe
#  exercises, C# exer
#  exercises, C# exerc
#  exercises, C# exerci
#  exercises, C# exercis
#  exercises, C# exercise
#  exercises, C# exercises
# e
# ex
# exe
# exer
# exerc
# exerci
# exercis
# exercise
# exercises
# exercises,
# exercises,
# exercises, C
# exercises, C#
# exercises, C#
# exercises, C# e
# exercises, C# ex
# exercises, C# exe
# exercises, C# exer
# exercises, C# exerc
# exercises, C# exerci
# exercises, C# exercis
# exercises, C# exercise
# exercises, C# exercises
# x
# xe
# xer
# xerc
# xerci
# xercis
# xercise
# xercises
# xercises,
# xercises,
# xercises, C
# xercises, C#
# xercises, C#
# xercises, C# e
# xercises, C# ex
# xercises, C# exe
# xercises, C# exer
# xercises, C# exerc
# xercises, C# exerci
# xercises, C# exercis
# xercises, C# exercise
# xercises, C# exercises
# e
# er
# erc
# erci
# ercis
# ercise
# ercises
# ercises,
# ercises,
# ercises, C
# ercises, C#
# ercises, C#
# ercises, C# e
# ercises, C# ex
# ercises, C# exe
# ercises, C# exer
# ercises, C# exerc
# ercises, C# exerci
# ercises, C# exercis
# ercises, C# exercise
# ercises, C# exercises
# r
# rc
# rci
# rcis
# rcise
# rcises
# rcises,
# rcises,
# rcises, C
# rcises, C#
# rcises, C#
# rcises, C# e
# rcises, C# ex
# rcises, C# exe
# rcises, C# exer
# rcises, C# exerc
# rcises, C# exerci
# rcises, C# exercis
# rcises, C# exercise
# rcises, C# exercises
# c
# ci
# cis
# cise
# cises
# cises,
# cises,
# cises, C
# cises, C#
# cises, C#
# cises, C# e
# cises, C# ex
# cises, C# exe
# cises, C# exer
# cises, C# exerc
# cises, C# exerci
# cises, C# exercis
# cises, C# exercise
# cises, C# exercises
# i
# is
# ise
# ises
# ises,
# ises,
# ises, C
# ises, C#
# ises, C#
# ises, C# e
# ises, C# ex
# ises, C# exe
# ises, C# exer
# ises, C# exerc
# ises, C# exerci
# ises, C# exercis
# ises, C# exercise
# ises, C# exercises
# s
# se
# ses
# ses,
# ses,
# ses, C
# ses, C#
# ses, C#
# ses, C# e
# ses, C# ex
# ses, C# exe
# ses, C# exer
# ses, C# exerc
# ses, C# exerci
# ses, C# exercis
# ses, C# exercise
# ses, C# exercises
# e
# es
# es,
# es,
# es, C
# es, C#
# es, C#
# es, C# e
# es, C# ex
# es, C# exe
# es, C# exer
# es, C# exerc
# es, C# exerci
# es, C# exercis
# es, C# exercise
# es, C# exercises
# s
# s,
# s,
# s, C
# s, C#
# s, C#
# s, C# e
# s, C# ex
# s, C# exe
# s, C# exer
# s, C# exerc
# s, C# exerci
# s, C# exercis
# s, C# exercise
# s, C# exercises
# ,
# ,
# , C
# , C#
# , C#
# , C# e
# , C# ex
# , C# exe
# , C# exer
# , C# exerc
# , C# exerci
# , C# exercis
# , C# exercise
# , C# exercises
#
#  C
#  C#
#  C#
#  C# e
#  C# ex
#  C# exe
#  C# exer
#  C# exerc
#  C# exerci
#  C# exercis
#  C# exercise
#  C# exercises
# C
# C#
# C#
# C# e
# C# ex
# C# exe
# C# exer
# C# exerc
# C# exerci
# C# exercis
# C# exercise
# C# exercises
# #
# #
# # e
# # ex
# # exe
# # exer
# # exerc
# # exerci
# # exercis
# # exercise
# # exercises
#
#  e
#  ex
#  exe
#  exer
#  exerc
#  exerci
#  exercis
#  exercise
#  exercises
# e
# ex
# exe
# exer
# exerc
# exerci
# exercis
# exercise
# exercises
# x
# xe
# xer
# xerc
# xerci
# xercis
# xercise
# xercises
# e
# er
# erc
# erci
# ercis
# ercise
# ercises
# r
# rc
# rci
# rcis
# rcise
# rcises
# c
# ci
# cis
# cise
# cises
# i
# is
# ise
# ises
# s
# se
# ses
# e
# es
# s

# %%
def find_substring_occurrences(input_string, substring):
    occurrences = []
    start = 0
    while start < len(input_string):
        position = input_string.find(substring, start)
        if position == -1:
            break
        occurrences.append((substring, position))
        start = position + 1
    return occurrences

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    target_substring = input("Enter the substring to find: ")
    
    occurrences = find_substring_occurrences(input_string, target_substring)
    
    if occurrences:
        print(f"Occurrences of '{target_substring}':")
        for substring, position in occurrences:
            print(f"'{substring}' found at position {position}")
    else:
        print(f"No occurrences of '{target_substring}' found.")
# Out:
# Enter a string: India is my country and I love my country very much
# Enter the substring to find: I love my country
# Occurrences of 'I love my country':
# 'I love my country' found at position 24

# %%
from datetime import datetime

def convert_date_format(input_date):
    # Parse the input date in yyyy-mm-dd format
    date_object = datetime.strptime(input_date, '%Y-%m-%d')
    
    # Convert the date to dd-mm-yyyy format
    formatted_date = date_object.strftime('%d-%m-%Y')
    
    return formatted_date

if __name__ == "__main__":
    input_date = input("Enter a date in yyyy-mm-dd format: ")
    
    try:
        converted_date = convert_date_format(input_date)
        print("Converted date:", converted_date)
    except ValueError:
        print("Invalid date format. Please use yyyy-mm-dd format.")
# Out:
# Enter a date in yyyy-mm-dd format: 1987-02-11
# Converted date: 11-02-1987

# %%
import re

def find_decimal_numbers(input_string):
    pattern = re.compile(r'\b\d+\.\d{1,2}\b')
    decimal_numbers = pattern.findall(input_string)
    return decimal_numbers

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    decimal_numbers = find_decimal_numbers(input_string)
    
    if decimal_numbers:
        print("Decimal numbers with precision of 1 or 2:")
        for number in decimal_numbers:
            print(number)
    else:
        print("No decimal numbers with precision of 1 or 2 found.")
# Out:
# Enter a string:  This watch cost me $ 12.75 whereas this bag cost me $ 12.789
# Decimal numbers with precision of 1 or 2:
# 12.75

# %%
def separate_numbers_and_positions(input_string):
    numbers = []
    positions = []
    
    for idx, char in enumerate(input_string):
        if char.isdigit():
            numbers.append(char)
            positions.append(idx)
    
    return numbers, positions

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    numbers, positions = separate_numbers_and_positions(input_string)
    
    if numbers:
        print("Numbers and their positions:")
        for num, pos in zip(numbers, positions):
            print(f"Number: {num}, Position: {pos}")
    else:
        print("No numbers found in the string.")
# Out:
# Enter a string: 24 volloby West 76, sydney , Australia
# Numbers and their positions:
# Number: 2, Position: 0
# Number: 4, Position: 1
# Number: 7, Position: 16
# Number: 6, Position: 17

# %%
import re

def extract_max_numeric_value(input_string):
    numeric_values = re.findall(r'\d+(\.\d+)?', input_string)
    
    if numeric_values:
        max_value = max(map(float, numeric_values))
        return max_value
    else:
        return None

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    max_numeric_value = extract_max_numeric_value(input_string)
    
    if max_numeric_value is not None:
        print("Maximum numeric value:", max_numeric_value)
    else:
        print("No numeric values found in the string.")
# Out:
# Enter a string: My name is Kushagra Sharma
# No numeric values found in the string.

# %%
import re

def insert_spaces_between_capital_words(input_string):
    pattern = r'([A-Z][a-z]*)'
    modified_string = re.sub(pattern, r' \1', input_string)
    return modified_string.strip()

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    modified_string = insert_spaces_between_capital_words(input_string)
    print("Modified string:", modified_string)
# Out:
# Enter a string: RegularExpressionIsAnImportantTopicInPython
# Modified string: Regular Expression Is An Important Topic In Python

# %%
import re

def find_uppercase_followed_by_lowercase(input_string):
    pattern = r'[A-Z][a-z]+'
    matches = re.findall(pattern, input_string)
    return matches

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    result = find_uppercase_followed_by_lowercase(input_string)
    
    if result:
        print("Sequences of one uppercase letter followed by lowercase letters:")
        for match in result:
            print(match)
    else:
        print("No matches found.")
# Out:
# Enter a string: THIS is the Inform That I Am Lucky
# Sequences of one uppercase letter followed by lowercase letters:
# Inform
# That
# Am
# Lucky

# %%
import re

def remove_continuous_duplicates(sentence):
    pattern = r'\b(\w+)(\s+\1)+\b'
    modified_sentence = re.sub(pattern, r'\1', sentence)
    return modified_sentence

if __name__ == "__main__":
    input_sentence = input("Enter a sentence: ")
    modified_sentence = remove_continuous_duplicates(input_sentence)
    print("Modified sentence:", modified_sentence)
# Out:
# Enter a sentence: Hello hello world world
# Modified sentence: Hello hello world

# %%
import re

def is_valid_string(input_string):
    pattern = r'^.*[A-Za-z0-9]$'
    return re.match(pattern, input_string) is not None

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    
    if is_valid_string(input_string):
        print("The string is valid.")
    else:
        print("The string is not valid.")
# Out:
# Enter a string: I am staying at 1280 , Chatta, Madan Gopal Nagar Delhi6
# The string is valid.

# %%
import re

def extract_hashtags(input_string):
    pattern = r'#\w+'
    hashtags = re.findall(pattern, input_string)
    return hashtags

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    hashtags = extract_hashtags(input_string)
    
    if hashtags:
        print("Extracted hashtags:")
        for tag in hashtags:
            print(tag)
    else:
        print("No hashtags found in the string.")
# Out:
# Enter a string: """RT @kapil_kausik: #Doltiwal I mean #xyzabc is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo"""
# Extracted hashtags:
# #Doltiwal
# #xyzabc
# #Demonetization

# %%
# %cd C:\Users\HP\Desktop
# Out:
# C:\Users\HP\Desktop

# %%
# %pwd
# Out:
# 'C:\\Users\\HP\\Desktop'

# %%
import re

def extract_dates_from_file(C:\Users\HP\Desktop\text.txt):
    with open(C:\Users\HP\Desktop\text.txt, 'r') as file:
        content = file.read()

    pattern = r'\b\d{1,2}/\d{1,2}/\d{4}\b'  # Assuming date format: dd/mm/yyyy
    dates = re.findall(pattern, content)
    return dates

if __name__ == "__main__":
    file_path = "C:\Users\HP\Desktop\text.txt"  # Replace with your file path
    
    extracted_dates = extract_dates_from_file(C:\Users\HP\Desktop\text.txt)
    if extracted_dates:
        print("Extracted dates:")
        for date in extracted_dates:
            print(date)
    else:
        print("No dates found in the text file.")
# Out:
#   Cell In[77], line 3
#     def extract_dates_from_file(C:\Users\HP\Desktop\text.txt):
#                                    ^
# SyntaxError: unexpected character after line continuation character

# %%
import re

def remove_words_by_length(input_string):
    pattern = re.compile(r'\b\w{2,4}\b')
    modified_string = pattern.sub('', input_string)
    return modified_string

if __name__ == "__main__":
    input_string = input("Enter a string: ")
    modified_string = remove_words_by_length(input_string)
    print("Modified string:", modified_string)
# Out:
# Enter a string: The following example creates an ArrayList with a capacity of 50 elements. 4 elements are then added to the ArrayList and the ArrayList is trimmed accordingly.
# Modified string:  following example creates  ArrayList  a capacity   elements. 4 elements   added   ArrayList   ArrayList  trimmed accordingly.
